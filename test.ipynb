# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiladitya1995/Python-Workshop/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Python programming")
# Out:
# Welcome to Python programming

# %%
e=[10,20,30]

# %%
print (e)
# Out:
# [10, 20, 30]

# %%
print(e[0])
# Out:
# 10
